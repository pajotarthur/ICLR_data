# %%
import pandas as pd
import matplotlib.pylab as plt
import numpy as np
import matplotlib.cm as cm
import seaborn
seaborn.set()
# %matplotlib inline

# %%
### Loading dataframe
df_paper = pd.read_json('./paper_df.json')
df_author = pd.read_json('./author_df.json')
df_inst = pd.read_json('./inst_df.json')
df_country = pd.read_json('./country_df.json')
df_paper = df_paper.drop([0]) # has nan
# All data are available at https://github.com/pajotarthur/ICLR_data

# %% [markdown]
# ## Average score of the papers, for each type of decision

# %%
groupby_decision = df_paper.groupby('decision')
groupby_decision.aggregate(np.average).review
# Out:
# decision
# Accept (Oral)               7.304348
# Accept (Poster)             6.497877
# Invite to Workshop Track    5.362963
# Reject                      4.644313
# Name: review, dtype: float64

# %% [markdown]
# ## Histogram of the score

# %%
ag.plot(kind = 'bar', colormap = cm.Accent, width = 1,figsize=(15,10),stacked=True)
plt.show()

# %% [markdown]
# ## Histogram of the score, not stacked. The overlap is quite important

# %%
df = pd.DataFrame({'value': df_paper.review.round(1), 'type': df_paper.decision})
df['dummy'] = 1
ag = df.groupby(['value','type']).sum().unstack()
ag.columns = ag.columns.droplevel()

ag.plot(kind = 'bar', colormap = cm.Accent, width = 1,figsize=(15,10))
plt.show()

# %% [markdown]
# ## Top author for number of accepted paper

# %%
df_author.sort_values(['nb_poster','nb_oral','nb_workshop'],ascending=False).head(25)
# Out:
#                        avg_note  avg_oral  avg_poster  avg_reject  \
# Sergey Levine          6.000000  0.000000    6.333333    0.000000
# Yoshua Bengio          5.481481  0.000000    6.190476    5.000000
# Richard Socher         6.166667  0.000000    6.722222    5.444444
# Caiming Xiong          6.190476  0.000000    6.666667    5.000000
# Pieter Abbeel          6.166667  7.500000    6.333333    5.750000
# Dawn Song              5.909091  7.000000    6.583333    5.416667
# Ian Goodfellow         6.333333  0.000000    6.333333    0.000000
# Kyunghyun Cho          5.777778  0.000000    6.416667    4.500000
# Zachary C. Lipton      6.266667  0.000000    6.416667    5.666667
# Max Welling            6.533333  8.000000    6.777778    4.333333
# Ruslan Salakhutdinov   5.666667  7.333333    7.000000    4.250000
# Adam Trischler         6.266667  0.000000    6.555556    5.666667
# Oriol Vinyals          6.055556  0.000000    6.555556    5.500000
# Xi Chen                6.083333  0.000000    6.222222    0.000000
# Animashree Anandkumar  6.083333  0.000000    6.333333    5.333333
# Chelsea Finn           6.083333  0.000000    6.666667    4.333333
# Demis Hassabis         6.250000  0.000000    6.222222    6.333333
# Dengyong Zhou          6.333333  0.000000    6.333333    0.000000
# Douwe Kiela            7.000000  0.000000    7.000000    0.000000
# Jimmy Ba               6.555556  0.000000    6.555556    0.000000
# Lior Wolf              6.111111  0.000000    6.111111    0.000000
# Ludovic Denoyer        6.777778  0.000000    6.777778    0.000000
# Lukasz Kaiser          5.944444  0.000000    7.000000    4.888889
# Nando de Freitas       5.500000  0.000000    5.777778    4.666667
# Nicolas Heess          5.466667  0.000000    6.555556    3.833333
#
#                        avg_workshop                            id  \
# Sergey Levine              5.222222    svlevine@eecs.berkeley.edu
# Yoshua Bengio              5.166667      bengioy@iro.umontreal.ca
# Richard Socher             5.000000            richard@socher.org
# Caiming Xiong              0.000000         cxiong@salesforce.com
# Pieter Abbeel              5.333333       pabbeel@cs.berkeley.edu
# Dawn Song                  5.000000            dawnsong@gmail.com
# Ian Goodfellow             0.000000         goodfellow@google.com
# Kyunghyun Cho              0.000000         kyunghyun.cho@nyu.edu
# Zachary C. Lipton          0.000000               zlipton@cmu.edu
# Max Welling                0.000000              m.welling@uva.nl
# Ruslan Salakhutdinov       0.000000           rsalakhu@cs.cmu.edu
# Adam Trischler             6.000000  adam.trischler@microsoft.com
# Oriol Vinyals              5.666667            vinyals@google.com
# Xi Chen                    5.666667              adslcx@gmail.com
# Animashree Anandkumar      0.000000          animakumar@gmail.com
# Chelsea Finn               0.000000       pabbeel@cs.berkeley.edu
# Demis Hassabis             0.000000           wierstra@google.com
# Dengyong Zhou              0.000000           dennyzhou@gmail.com
# Douwe Kiela                0.000000                 dkiela@fb.com
# Jimmy Ba                   0.000000         jimmy@psi.toronto.edu
# Lior Wolf                  0.000000            liorwolf@gmail.com
# Ludovic Denoyer            0.000000       ludovic.denoyer@upmc.fr
# Lukasz Kaiser              0.000000       lukaszkaiser@google.com
# Nando de Freitas           0.000000     nandodefreitas@google.com
# Nicolas Heess              0.000000              heess@google.com
#
#                              institution institution_country  nb_oral  \
# Sergey Levine          eecs.berkeley.edu                 edu        0
# Yoshua Bengio           iro.umontreal.ca                  ca        0
# Richard Socher                socher.org                 org        0
# Caiming Xiong             salesforce.com                 com        0
# Pieter Abbeel            cs.berkeley.edu                 edu        2
# Dawn Song                      gmail.com                 com        1
# Ian Goodfellow                google.com                 com        0
# Kyunghyun Cho                    nyu.edu                 edu        0
# Zachary C. Lipton                cmu.edu                 edu        0
# Max Welling                       uva.nl                  nl        1
# Ruslan Salakhutdinov          cs.cmu.edu                 edu        1
# Adam Trischler             microsoft.com                 com        0
# Oriol Vinyals                 google.com                 com        0
# Xi Chen                        gmail.com                 com        0
# Animashree Anandkumar          gmail.com                 com        0
# Chelsea Finn             cs.berkeley.edu                 edu        0
# Demis Hassabis                google.com                 com        0
# Dengyong Zhou                  gmail.com                 com        0
# Douwe Kiela                       fb.com                 com        0
# Jimmy Ba                 psi.toronto.edu                 edu        0
# Lior Wolf                      gmail.com                 com        0
# Ludovic Denoyer                  upmc.fr                  fr        0
# Lukasz Kaiser                 google.com                 com        0
# Nando de Freitas              google.com                 com        0
# Nicolas Heess                 google.com                 com        0
#
#                        nb_paper  nb_poster  nb_reject  nb_workshop
# Sergey Levine                10          7          0            3
# Yoshua Bengio                18          7          9            2
# Richard Socher               10          6          3            1
# Caiming Xiong                 7          5          2            0
# Pieter Abbeel                12          4          4            2
# Dawn Song                    11          4          4            2
# Ian Goodfellow                4          4          0            0
# Kyunghyun Cho                 6          4          2            0
# Zachary C. Lipton             5          4          1            0
# Max Welling                   5          3          1            0
# Ruslan Salakhutdinov          8          3          4            0
# Adam Trischler                5          3          1            1
# Oriol Vinyals                 6          3          2            1
# Xi Chen                       4          3          0            1
# Animashree Anandkumar         4          3          1            0
# Chelsea Finn                  4          3          1            0
# Demis Hassabis                4          3          1            0
# Dengyong Zhou                 3          3          0            0
# Douwe Kiela                   3          3          0            0
# Jimmy Ba                      3          3          0            0
# Lior Wolf                     3          3          0            0
# Ludovic Denoyer               3          3          0            0
# Lukasz Kaiser                 6          3          3            0
# Nando de Freitas              4          3          1            0
# Nicolas Heess                 5          3          2            0

# %% [markdown]
# ## Top author for number of submitted paper

# %%
df_author.sort_values(['nb_paper'],ascending=False).head(10)
# Out:
#                       avg_note  avg_oral  avg_poster  avg_reject  \
# Yoshua Bengio         5.481481  0.000000    6.190476    5.000000
# Pieter Abbeel         6.166667  7.500000    6.333333    5.750000
# Dawn Song             5.909091  7.000000    6.583333    5.416667
# Sergey Levine         6.000000  0.000000    6.333333    0.000000
# Richard Socher        6.166667  0.000000    6.722222    5.444444
# Quoc V. Le            5.148148  0.000000    6.166667    4.444444
# Ruslan Salakhutdinov  5.666667  7.333333    7.000000    4.250000
# Caiming Xiong         6.190476  0.000000    6.666667    5.000000
# Kyunghyun Cho         5.777778  0.000000    6.416667    4.500000
# Lukasz Kaiser         5.944444  0.000000    7.000000    4.888889
#
#                       avg_workshop                          id  \
# Yoshua Bengio             5.166667    bengioy@iro.umontreal.ca
# Pieter Abbeel             5.333333     pabbeel@cs.berkeley.edu
# Dawn Song                 5.000000          dawnsong@gmail.com
# Sergey Levine             5.222222  svlevine@eecs.berkeley.edu
# Richard Socher            5.000000          richard@socher.org
# Quoc V. Le                5.166667             adai@google.com
# Ruslan Salakhutdinov      0.000000         rsalakhu@cs.cmu.edu
# Caiming Xiong             0.000000       cxiong@salesforce.com
# Kyunghyun Cho             0.000000       kyunghyun.cho@nyu.edu
# Lukasz Kaiser             0.000000     lukaszkaiser@google.com
#
#                             institution institution_country  nb_oral  \
# Yoshua Bengio          iro.umontreal.ca                  ca        0
# Pieter Abbeel           cs.berkeley.edu                 edu        2
# Dawn Song                     gmail.com                 com        1
# Sergey Levine         eecs.berkeley.edu                 edu        0
# Richard Socher               socher.org                 org        0
# Quoc V. Le                   google.com                 com        0
# Ruslan Salakhutdinov         cs.cmu.edu                 edu        1
# Caiming Xiong            salesforce.com                 com        0
# Kyunghyun Cho                   nyu.edu                 edu        0
# Lukasz Kaiser                google.com                 com        0
#
#                       nb_paper  nb_poster  nb_reject  nb_workshop
# Yoshua Bengio               18          7          9            2
# Pieter Abbeel               12          4          4            2
# Dawn Song                   11          4          4            2
# Sergey Levine               10          7          0            3
# Richard Socher              10          6          3            1
# Quoc V. Le                   9          2          3            4
# Ruslan Salakhutdinov         8          3          4            0
# Caiming Xiong                7          5          2            0
# Kyunghyun Cho                6          4          2            0
# Lukasz Kaiser                6          3          3            0

# %% [markdown]
# ## Top author for  average note. We choose (arbitrarly) to keep only the authors that submitted more than tree papers.

# %%
df_author[df_author.nb_paper > 3].sort_values(['avg_note'],ascending=False).head(10)
# Out:
#                    avg_note  avg_oral  avg_poster  avg_reject  avg_workshop  \
# Igor Mordatch      7.000000  7.500000    6.333333    6.666667      0.000000
# Amnon Shashua      6.916667  8.000000    6.833333    0.000000      6.000000
# Max Welling        6.533333  8.000000    6.777778    4.333333      0.000000
# Trevor Darrell     6.500000  7.666667    6.666667    6.333333      5.333333
# Jason D. Lee       6.500000  0.000000    7.500000    5.666667      5.333333
# Bo Li              6.466667  7.000000    6.833333    5.833333      0.000000
# Warren He          6.333333  0.000000    6.833333    5.833333      0.000000
# Ian Goodfellow     6.333333  0.000000    6.333333    0.000000      0.000000
# Adam Trischler     6.266667  0.000000    6.555556    5.666667      6.000000
# Zachary C. Lipton  6.266667  0.000000    6.416667    5.666667      0.000000
#
#                                              id        institution  \
# Igor Mordatch           igor.mordatch@gmail.com          gmail.com
# Amnon Shashua             shashua@cs.huji.ac.il      cs.huji.ac.il
# Max Welling                    m.welling@uva.nl             uva.nl
# Trevor Darrell         trevor@eecs.berkeley.edu  eecs.berkeley.edu
# Jason D. Lee              jasondlee88@gmail.com          gmail.com
# Bo Li                         lxbosky@gmail.com          gmail.com
# Warren He                  _w@eecs.berkeley.edu  eecs.berkeley.edu
# Ian Goodfellow            goodfellow@google.com         google.com
# Adam Trischler     adam.trischler@microsoft.com      microsoft.com
# Zachary C. Lipton               zlipton@cmu.edu            cmu.edu
#
#                   institution_country  nb_oral  nb_paper  nb_poster  \
# Igor Mordatch                     com        2         4          1
# Amnon Shashua                      il        1         4          2
# Max Welling                        nl        1         5          3
# Trevor Darrell                    edu        1         4          1
# Jason D. Lee                      com        0         4          2
# Bo Li                             com        1         5          2
# Warren He                         edu        0         4          2
# Ian Goodfellow                    com        0         4          4
# Adam Trischler                    com        0         5          3
# Zachary C. Lipton                 edu        0         5          4
#
#                    nb_reject  nb_workshop
# Igor Mordatch              1            0
# Amnon Shashua              0            1
# Max Welling                1            0
# Trevor Darrell             1            1
# Jason D. Lee               1            1
# Bo Li                      2            0
# Warren He                  2            0
# Ian Goodfellow             0            0
# Adam Trischler             1            1
# Zachary C. Lipton          1            0

# %% [markdown]
# ## Top institution for number of accepted paper.
#
# The institution have written 1 paper if all the authors are from the institution. Otherwise, if among 3 authors, only 1 is from the institution, they have written 1/3 of a paper. The institution have been scrapped from the author's email adress. There is probably more work to do, the code is available at  https://github.com/pajotarthur/ICLR_data/blob/master/add_paper_origin.ipynb. Email ending with gmail.com have been removed.

# %%
df_inst.sort_values(['nb_poster','nb_oral','nb_workshop'],ascending=False).head(10)
# Out:
#                    acceptance_rate  avg_nb_author  avg_note  avg_oral  \
# google.com                0.555341       4.998542  5.782389  7.400000
# Berkeley                  0.455809       4.336206  5.804083  7.326087
# Stanford                  0.367346       3.291708  5.648448  9.000000
# CMU                       0.284611       3.593539  5.348831  7.454545
# Facebook                  0.555811       4.004603  5.822401  5.333333
# Microsoft                 0.389166       4.412585  5.740885  7.714286
# Oxford University         0.601182       4.063424  5.727582  0.000000
# IBM                       0.304785       3.617225  5.619298  0.000000
# Toronto Univ.             0.533566       3.870968  6.194420  0.000000
# ETH                       0.435093       3.766049  5.593913  0.000000
#
#                    avg_poster  avg_reject  avg_workshop   nb_oral   nb_paper  \
# google.com           6.394221    4.898694      5.018868  3.333333  83.024206
# Berkeley             6.349743    5.191086      5.180204  2.555556  28.596429
# Stanford             6.919946    4.711551      5.535826  1.000000  28.252814
# CMU                  6.593513    4.742637      5.442982  0.916667  32.280159
# Facebook             6.656096    4.647059      5.450000  0.166667  14.483333
# Microsoft            6.757230    4.874873      5.775910  1.166667  21.755952
# Oxford University    6.285352    4.840000      5.666667  0.000000   8.859524
# IBM                  6.803244    5.029511      6.400000  0.000000  17.416667
# Toronto Univ.        6.666667    5.818182      5.539683  0.000000   9.558333
# ETH                  6.666667    4.767677      0.000000  0.000000  11.683333
#
#                    nb_poster  nb_reject  nb_workshop
# google.com         42.773449  28.084091     8.833333
# Berkeley           10.478968   9.303571     6.258333
# Stanford            9.378571  16.090909     1.783333
# CMU                 8.270635  20.559524     2.533333
# Facebook            7.883333   5.100000     1.333333
# Microsoft           7.300000  11.305952     1.983333
# Oxford University   5.326190   3.333333     0.200000
# IBM                 5.308333  11.483333     0.625000
# Toronto Univ.       5.100000   1.833333     2.625000
# ETH                 5.083333   6.600000     0.000000

# %% [markdown]
# ## Top institution for number of submitted paper.

# %%
df_inst.sort_values(['nb_paper'],ascending=False).head(10)
# Out:
#                   acceptance_rate  avg_nb_author  avg_note  avg_oral  \
# google.com               0.555341       4.998542  5.782389  7.400000
# CMU                      0.284611       3.593539  5.348831  7.454545
# Berkeley                 0.455809       4.336206  5.804083  7.326087
# Stanford                 0.367346       3.291708  5.648448  9.000000
# Microsoft                0.389166       4.412585  5.740885  7.714286
# MIT                      0.262715       3.682219  5.624772  7.333333
# IBM                      0.304785       3.617225  5.619298  0.000000
# Facebook                 0.555811       4.004603  5.822401  5.333333
# ETH                      0.435093       3.766049  5.593913  0.000000
# Washington Univ.         0.465472       4.287053  5.880742  7.190476
#
#                   avg_poster  avg_reject  avg_workshop   nb_oral   nb_paper  \
# google.com          6.394221    4.898694      5.018868  3.333333  83.024206
# CMU                 6.593513    4.742637      5.442982  0.916667  32.280159
# Berkeley            6.349743    5.191086      5.180204  2.555556  28.596429
# Stanford            6.919946    4.711551      5.535826  1.000000  28.252814
# Microsoft           6.757230    4.874873      5.775910  1.166667  21.755952
# MIT                 6.607670    5.191318      5.392157  0.500000  19.825000
# IBM                 6.803244    5.029511      6.400000  0.000000  17.416667
# Facebook            6.656096    4.647059      5.450000  0.166667  14.483333
# ETH                 6.666667    4.767677      0.000000  0.000000  11.683333
# Washington Univ.    6.787716    5.039764      5.000000  0.875000  11.429762
#
#                   nb_poster  nb_reject  nb_workshop
# google.com        42.773449  28.084091     8.833333
# CMU                8.270635  20.559524     2.533333
# Berkeley          10.478968   9.303571     6.258333
# Stanford           9.378571  16.090909     1.783333
# Microsoft          7.300000  11.305952     1.983333
# MIT                4.708333  10.366667     4.250000
# IBM                5.308333  11.483333     0.625000
# Facebook           7.883333   5.100000     1.333333
# ETH                5.083333   6.600000     0.000000
# Washington Univ.   4.445238   5.109524     1.000000

# %% [markdown]
# ## Top institution for  average note. We choose (arbitrarly) to keep only the institution that submitted more than tree papers.

# %%
df_inst[df_inst.nb_paper > 3].sort_values(['acceptance_rate'],ascending=False).head(10)
# Out:
#                    acceptance_rate  avg_nb_author  avg_note  avg_oral  \
# NVIDIA                    0.823799       5.739130  5.760488  5.666667
# Intel                     0.750000       6.750000  6.250000  0.000000
# cs.huji.ac.il             0.744681       3.063830  6.851064  8.000000
# uva.nl                    0.741294       3.582090  6.199005  8.000000
# salesforce.com            0.730290       3.485477  6.258645  0.000000
# Cambridge                 0.691223       3.785266  5.889498  0.000000
# seas.upenn.edu            0.678930       3.652174  5.948718  0.000000
# ttic.edu                  0.630631       2.972973  6.534535  0.000000
# Oxford University         0.601182       4.063424  5.727582  0.000000
# Princeton                 0.562044       4.029197  5.693431  0.000000
#
#                    avg_poster  avg_reject  avg_workshop   nb_oral  nb_paper  \
# NVIDIA               6.280702    4.380952      0.000000  1.000000  3.310606
# Intel                6.777778    4.666667      0.000000  0.000000  4.000000
# cs.huji.ac.il        6.888889    0.000000      6.000000  0.666667  3.916667
# uva.nl               6.820896    4.076923      0.000000  0.250000  3.350000
# salesforce.com       6.704545    5.066667      5.000000  0.000000  4.016667
# Cambridge            6.190476    5.215736      0.000000  0.000000  6.076190
# seas.upenn.edu       6.436782    4.916667      0.000000  0.000000  3.559524
# ttic.edu             7.095238    5.333333      5.809524  0.000000  3.700000
# Oxford University    6.285352    4.840000      5.666667  0.000000  8.859524
# Princeton            6.363636    4.500000      5.333333  0.000000  5.708333
#
#                    nb_poster  nb_reject  nb_workshop
# NVIDIA              1.727273   0.583333         0.00
# Intel               3.000000   1.000000         0.00
# cs.huji.ac.il       2.250000   0.000000         1.00
# uva.nl              2.233333   0.866667         0.00
# salesforce.com      2.933333   0.833333         0.25
# Cambridge           4.200000   1.876190         0.00
# seas.upenn.edu      2.416667   1.142857         0.00
# ttic.edu            2.333333   0.666667         0.70
# Oxford University   5.326190   3.333333         0.20
# Princeton           3.208333   1.500000         1.00

# %% [markdown]
# ## Decision bar plot, for each institution

# %%
df_inst[df_inst.nb_poster > 1][['nb_poster','nb_reject','nb_oral','nb_workshop']].sort_values(by='nb_poster').plot.bar(figsize=(15,10),legend=True,fontsize=15,stacked=True)

# %% [markdown]
# ##  Bar plot of the number of accepted paper by institution

# %%
df_inst[df_inst.nb_poster > 1].nb_poster.sort_values().plot.bar(figsize=(15,10),legend=False,fontsize=20)

# %% [markdown]
# ## Top country for number of accepted paper.

# %%
df_country.sort_values(['nb_poster','nb_oral','nb_workshop'],ascending=False).head(10)
# Out:
#      acceptance_rate  avg_note  avg_oral  avg_poster  avg_reject  \
# com         0.407407  5.512671  7.145833    6.485320    4.724359
# edu         0.392377  5.532885  7.238095    6.501035    4.752252
# uk          0.390625  5.328125  0.000000    6.280000    4.648649
# ca          0.354167  5.236111  8.000000    6.604167    4.240000
# fr          0.428571  5.654762  0.000000    6.750000    4.904762
# de          0.289474  5.368421  8.000000    6.500000    4.782609
# ch          0.321429  5.309524  0.000000    6.370370    4.705882
# org         0.346154  5.525641  0.000000    6.629630    4.888889
# cn          0.200000  5.180000  6.555556    6.523810    4.644444
# jp          0.428571  5.714286  7.166667    6.571429    4.814815
#
#      avg_workshop  nb_oral  nb_paper  nb_poster  nb_reject  nb_workshop
# com      5.310606       16       513        193        260           44
# edu      5.401361       14       446        161        222           49
# uk       6.000000        0        64         25         37            2
# ca       5.277778        1        48         16         25            6
# fr       4.333333        0        28         12         14            2
# de       5.250000        1        38         10         23            4
# ch       5.666667        0        28          9         17            2
# org      5.333333        0        26          9         15            2
# cn       5.433333        3        50          7         30           10
# jp       5.444444        2        21          7          9            3

# %% [markdown]
# ## Top country for number of submitted paper.

# %%
df_country.sort_values(['nb_paper'],ascending=False).head(10)
# Out:
#      acceptance_rate  avg_note  avg_oral  avg_poster  avg_reject  \
# com         0.407407  5.512671  7.145833    6.485320    4.724359
# edu         0.392377  5.532885  7.238095    6.501035    4.752252
# uk          0.390625  5.328125  0.000000    6.280000    4.648649
# cn          0.200000  5.180000  6.555556    6.523810    4.644444
# ca          0.354167  5.236111  8.000000    6.604167    4.240000
# de          0.289474  5.368421  8.000000    6.500000    4.782609
# fr          0.428571  5.654762  0.000000    6.750000    4.904762
# ch          0.321429  5.309524  0.000000    6.370370    4.705882
# org         0.346154  5.525641  0.000000    6.629630    4.888889
# jp          0.428571  5.714286  7.166667    6.571429    4.814815
#
#      avg_workshop  nb_oral  nb_paper  nb_poster  nb_reject  nb_workshop
# com      5.310606       16       513        193        260           44
# edu      5.401361       14       446        161        222           49
# uk       6.000000        0        64         25         37            2
# cn       5.433333        3        50          7         30           10
# ca       5.277778        1        48         16         25            6
# de       5.250000        1        38         10         23            4
# fr       4.333333        0        28         12         14            2
# ch       5.666667        0        28          9         17            2
# org      5.333333        0        26          9         15            2
# jp       5.444444        2        21          7          9            3

# %% [markdown]
# ## Top country by acceptance rate.

# %%
df_country[df_country.nb_paper > 5].sort_values(['acceptance_rate'],ascending=False).head(10)
# Out:
#      acceptance_rate  avg_note  avg_oral  avg_poster  avg_reject  \
# nl          0.583333  5.916667  8.000000    6.944444    4.266667
# au          0.571429  5.857143  7.000000    6.333333    5.000000
# il          0.500000  6.133333  8.000000    6.833333    4.888889
# jp          0.428571  5.714286  7.166667    6.571429    4.814815
# fr          0.428571  5.654762  0.000000    6.750000    4.904762
# com         0.407407  5.512671  7.145833    6.485320    4.724359
# edu         0.392377  5.532885  7.238095    6.501035    4.752252
# uk          0.390625  5.328125  0.000000    6.280000    4.648649
# kr          0.375000  5.187500  0.000000    6.388889    4.370370
# ca          0.354167  5.236111  8.000000    6.604167    4.240000
#
#      avg_workshop  nb_oral  nb_paper  nb_poster  nb_reject  nb_workshop
# nl       0.000000        1        12          6          5            0
# au       0.000000        1         7          3          3            0
# il       5.666667        1        10          4          3            2
# jp       5.444444        2        21          7          9            3
# fr       4.333333        0        28         12         14            2
# com      5.310606       16       513        193        260           44
# edu      5.401361       14       446        161        222           49
# uk       6.000000        0        64         25         37            2
# kr       5.333333        0        16          6          9            1
# ca       5.277778        1        48         16         25            6

# %% [markdown]
# ## Decision bar plot, for each country

# %%
df_country[df_country.nb_poster > 1][['nb_poster','nb_reject','nb_oral','nb_workshop']].sort_values(by='nb_poster').plot.bar(figsize=(15,10),legend=True,fontsize=15,stacked=True)

# %% [markdown]
# ##  Bar plot of the number of accepted paper by country

# %%
df_country[df_country.nb_paper >1].nb_paper.sort_values().plot.bar(figsize=(15,10),legend=False,fontsize=25)
